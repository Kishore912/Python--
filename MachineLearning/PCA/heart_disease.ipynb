# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\tmachine\AppData\Local\Temp\ipykernel_2548\1694581189.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("E:\T-Machine\python\heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df[df.Cholesterol>(df.Cholesterol.mean()+3*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
df1 = df[df.Cholesterol<=(df.Cholesterol.mean()+3*df.Cholesterol.std())]

# %%
df[df.RestingBP>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
df2 = df1[df1.RestingBP<=(df1.RestingBP.mean()+3*df1.RestingBP.std())]

# %%
df[df.FastingBS>(df.FastingBS.mean()+3*df.FastingBS.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df.MaxHR>(df.MaxHR.mean()+3*df.MaxHR.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df.Oldpeak>(df.Oldpeak.mean()+3*df.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166    140              Y      5.0     Flat             1
# 702    145              N      4.2     Down             0
# 771    111              Y      5.6     Down             1
# 791    122              Y      4.2     Flat             1
# 850    145              N      6.2     Down             1
# 900    140              N      4.4     Down             1

# %%
df3 = df2[df2.Oldpeak<=(df2.Oldpeak.mean()+3*df2.Oldpeak.std())]

# %%
df3.shape
# Out:
# (902, 12)

# %%
df3
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df3['Sex'] = le.fit_transform(df3['Sex'].astype(str))
df3['RestingECG'] = le.fit_transform(df3['RestingECG'])
df3['ExerciseAngina'] = le.fit_transform(df3['ExerciseAngina'])
df3['ST_Slope'] = le.fit_transform(df3['ST_Slope'])
# Out:
# C:\Users\tmachine\AppData\Local\Temp\ipykernel_2548\3527396131.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Sex'] = le.fit_transform(df3['Sex'].astype(str))
# C:\Users\tmachine\AppData\Local\Temp\ipykernel_2548\3527396131.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['RestingECG'] = le.fit_transform(df3['RestingECG'])
# C:\Users\tmachine\AppData\Local\Temp\ipykernel_2548\3527396131.py:5: SettingWithCopyWarning:
# ...

# %%
df3
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1           ATA        140          289          0           1
# 1     49    0           NAP        160          180          0           1
# 2     37    1           ATA        130          283          0           2
# 3     48    0           ASY        138          214          0           1
# 4     54    1           NAP        150          195          0           1
# ..   ...  ...           ...        ...          ...        ...         ...
# 913   45    1            TA        110          264          0           1
# 914   68    1           ASY        144          193          1           1
# 915   57    1           ASY        130          131          0           1
# 916   57    0           ATA        130          236          0           0
# 917   38    1           NAP        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# ...

# %%
df4 = df3.copy()

# %%
chest_pain_dummies = pd.get_dummies(df4['ChestPainType'],prefix='ChestPainType',drop_first=True)
chest_pain_dummies
# Out:
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0                 True              False             False
# 1                False               True             False
# 2                 True              False             False
# 3                False              False             False
# 4                False               True             False
# ..                 ...                ...               ...
# 913              False              False              True
# 914              False              False             False
# 915              False              False             False
# 916               True              False             False
# 917              False               True             False
#
# [902 rows x 3 columns]

# %%
chest_pain_dummies = chest_pain_dummies.astype(int)
chest_pain_dummies
# Out:
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0                    1                  0                 0
# 1                    0                  1                 0
# 2                    1                  0                 0
# 3                    0                  0                 0
# 4                    0                  1                 0
# ..                 ...                ...               ...
# 913                  0                  0                 1
# 914                  0                  0                 0
# 915                  0                  0                 0
# 916                  1                  0                 0
# 917                  0                  1                 0
#
# [902 rows x 3 columns]

# %%
df4.drop(columns=['ChestPainType'],inplace=True)
df5 = pd.concat([df4,chest_pain_dummies],axis=1)
df5.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0   40    1        140          289          0           1    172
# 1   49    0        160          180          0           1    156
# 2   37    1        130          283          0           2     98
# 3   48    0        138          214          0           1    108
# 4   54    1        150          195          0           1    122
#
#    ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  ChestPainType_ATA  \
# 0               0      0.0         2             0                  1
# 1               0      1.0         1             1                  0
# 2               0      0.0         2             0                  1
# 3               1      1.5         1             1                  0
# 4               0      0.0         2             0                  0
#
#    ChestPainType_NAP  ChestPainType_TA
# 0                  0                 0
# 1                  1                 0
# ...

# %%
# df4['ChestPainType'] = df4['ChestPainType'].astype('category')

# # Perform one-hot encoding
# chest_pain_dummies = pd.get_dummies(df4['ChestPainType'], prefix='ChestPainType', drop_first=True)

# # Cast boolean values to integers (0s and 1s)
# chest_pain_dummies = chest_pain_dummies.astype(int)

# # Drop the original ChestPainType column
# df4.drop(columns=['ChestPainType'], inplace=True)

# # Concatenate the one-hot encoded columns with the DataFrame
# df5 = pd.concat([df4, chest_pain_dummies], axis=1)

# df5.head()

# %%
X=df5.drop('HeartDisease',axis=1)
y=df5.HeartDisease

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_scaled = scale.fit_transform(X)
X_scaled
# Out:
# array([[-1.42896269,  0.51485643,  0.46089071, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-0.47545956, -1.94228905,  1.5925728 , ..., -0.4836591 ,
#          1.86750159, -0.22914788],
#        [-1.74679706,  0.51485643, -0.10495034, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        ...,
#        [ 0.37209878,  0.51485643, -0.10495034, ..., -0.4836591 ,
#         -0.53547478, -0.22914788],
#        [ 0.37209878, -1.94228905, -0.10495034, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-1.64085227,  0.51485643,  0.3477225 , ..., -0.4836591 ,
#          1.86750159, -0.22914788]])

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X_scaled,y,test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (721, 13)
# (181, 13)
# (721,)
# (181,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
lg = LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lg.score(X_test,y_test)
# Out:
# 0.8784530386740331

# %%
sv = SVC()
sv.fit(X_train,y_train)
# Out:
# SVC()

# %%
sv.score(X_test,y_test)
# Out:
# 0.8839779005524862

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(X_test,y_test)
# Out:
# 0.8839779005524862

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95)
X_pca = pca.fit_transform(X)
X_pca.shape
# Out:
# (902, 2)

# %%
X_train_pca , X_test_pca , y_train_pca , y_test_pca = train_test_split(X_pca,y,test_size=0.2)

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train_pca,y_train_pca)
rf.score(X_test_pca,y_test_pca)
# Out:
# 0.6961325966850829
