# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
wine_data=pd.read_csv("E:/T-Machine/wine+quality/winequality-white.csv",names=[ 

"Fixed Acidity", "Volatile Acidity", "Citric Acid", "Residual Sugar",
"Chlorides", "Free Sulfur Dioxide", "Total Sulfur Dioxide", "Density",
"pH", "Sulphates", "Alcohol", "Quality"],skiprows=1,sep=r'\s*;\s*')
# Out:
# C:\Users\tmachine\AppData\Local\Temp\ipykernel_21388\3047007885.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   wine_data=pd.read_csv("E:/T-Machine/wine+quality/winequality-white.csv",names=[

# %%
wine_data.head()
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    Free Sulfur Dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    Alcohol  Quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
import seaborn as sns
corrmat = wine_data.corr()
plt.figure(figsize=(20,6))
sns.heatmap(corrmat,annot=True,fmt='.2f',square=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X=wine_data.values[:,0:11]
Y=wine_data.values[:,11]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion="entropy",max_depth=5,max_features=5)

# %%
classifier.fit(X_train,Y_train)
y_predict=classifier.predict(X_test)
print(y_predict[0:5])
# Out:
# [5. 6. 6. 6. 6.]

# %%
#predicting accuracy method 1
from sklearn.metrics import accuracy_score
accuracy1 = accuracy_score(y_predict,Y_test)
accuracy1
# Out:
# 0.5071428571428571

# %%
#predicting accuracy method2
accuracy2 = classifier.score(X_test,Y_test)
accuracy2
# Out:
# 0.5071428571428571
