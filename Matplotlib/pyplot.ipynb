# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xPoints = np.array([0,60])
yPoints = np.array([0,250])
plt.plot(xPoints,yPoints)
plt.show()

# %%
xPoints = np.array([1,250])
yPoints = np.array([0,250])
plt.plot(xPoints,yPoints)
plt.show()
